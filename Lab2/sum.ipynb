# %%
# Specify the file path
file_path = 'output.txt'

# Open the file and read it line by line
lines = []

with open(file_path, 'r') as file:
    for line in file:
        # Process each line as needed
        lines.append(float(line.strip()))

# %%
pop_measure_lock = []
pop_measure_cas = []
push_measure_lock = []
push_measure_cas = []
counter = 0


for i in range(1, 9):
    
    pop_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_lock)

for i in range(1, 9):
    
    pop_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_cas)

for i in range(1, 9):
    
    push_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_lock)

for i in range(1, 9):
    
    push_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_cas)
# Out:
# [0.236538, 0.783369, 0.497365, 0.54523175, 0.6142818000000001, 0.610506, 0.6660757142857143, 0.6648768749999999]
# [0.20469, 0.172823, 0.2627916666666667, 0.19062125, 0.1750086, 0.2602756666666666, 0.28275014285714284, 0.31640787500000006]
# [0.29764, 0.66803, 0.5756073333333335, 0.5965812500000001, 0.5851154, 0.6224338333333334, 0.6157434285714285, 0.62932875]
# [0.308985, 0.246604, 0.27038133333333336, 0.31874800000000003, 0.2826772, 0.31929466666666667, 0.4043074285714286, 0.405059125]

# %%
import matplotlib.pyplot as plt


plt.plot(pop_measure_lock, label='pop_measure_lock')
plt.plot(pop_measure_cas, label='pop_measure_cas')
plt.plot(push_measure_lock, label='push_measure_lock')
plt.plot(push_measure_cas, label='push_measure_cas')

# Adding labels and title
plt.xlabel('THREADS')
plt.ylabel('TIME')
plt.title('TIMINIG')

# Adding legend
plt.legend()

# Display the plot
plt.show()

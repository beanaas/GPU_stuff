# %%
# Specify the file path
file_path = 'output.txt'

# Open the file and read it line by line
lines = []

with open(file_path, 'r') as file:
    for line in file:
        # Process each line as needed
        lines.append(float(line.strip()))

# %%
pop_measure_lock = []
pop_measure_cas = []
push_measure_lock = []
push_measure_cas = []
counter = 0


for i in range(1, 9):
    
    pop_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_lock)

for i in range(1, 9):
    
    pop_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_cas)

for i in range(1, 9):
    
    push_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_lock)

for i in range(1, 9):
    
    push_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_cas)
# Out:
# [0.132296, 0.235596, 0.16944166666666668, 0.24114125, 0.28248660000000003, 0.2888418333333333, 0.3669472857142857, 0.394371125]
# [0.07356, 0.279358, 0.3025366666666667, 0.39803249999999996, 0.3575564, 0.3964068333333333, 0.48381414285714286, 0.446392375]
# [0.129247, 0.24735400000000002, 0.178906, 0.25460325, 0.308739, 0.340557, 0.33643528571428577, 0.37154925]
# [0.084503, 0.2234525, 0.3054206666666666, 0.3152635, 0.33639920000000006, 0.3619885, 0.3483422857142857, 0.36816625]

# %%
import matplotlib.pyplot as plt


plt.plot(pop_measure_lock, label='pop_measure_lock')
plt.plot(pop_measure_cas, label='pop_measure_cas')
plt.plot(push_measure_lock, label='push_measure_lock')
plt.plot(push_measure_cas, label='push_measure_cas')

# Adding labels and title
plt.xlabel('THREADS')
plt.ylabel('TIME')
plt.title('TIMINIG')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
# Specify the file path
file_path = 'output.txt'

# Open the file and read it line by line
lines = []

with open(file_path, 'r') as file:
    for line in file:
        # Process each line as needed
        lines.append(float(line.strip()))

# %%
pop_measure_lock = []
pop_measure_cas = []
push_measure_lock = []
push_measure_cas = []
counter = 0


for i in range(1, 9):
    
    pop_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_lock)

for i in range(1, 9):
    
    pop_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_cas)

for i in range(1, 9):
    
    push_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_lock)

for i in range(1, 9):
    
    push_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_cas)
# Out:
# [0.011398, 0.034950999999999996, 0.029889666666666665, 0.032286, 0.042015199999999996, 0.04196266666666667, 0.04808585714285714, 0.048359625]
# [0.009017, 0.030295000000000002, 0.051725999999999994, 0.04572575, 0.0703448, 0.07973466666666666, 0.07880614285714287, 0.09088737499999999]
# [0.046275, 0.1181525, 0.06891966666666667, 0.06968175, 0.0743058, 0.07835583333333333, 0.07695357142857143, 0.084249625]
# [0.037703, 0.0447845, 0.05718, 0.0894015, 0.09740199999999999, 0.09484999999999999, 0.09842185714285714, 0.095217625]

# %%
import matplotlib.pyplot as plt


plt.plot(pop_measure_lock, label='pop_measure_lock')
plt.plot(pop_measure_cas, label='pop_measure_cas')
plt.plot(push_measure_lock, label='push_measure_lock')
plt.plot(push_measure_cas, label='push_measure_cas')

# Adding labels and title
plt.xlabel('THREADS')
plt.ylabel('TIME')
plt.title('TIMINIG')

# Adding legend
plt.legend()

# Display the plot
plt.show()

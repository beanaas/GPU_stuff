# %%
# Specify the file path
file_path = 'output.txt'

# Open the file and read it line by line
lines = []

with open(file_path, 'r') as file:
    for line in file:
        # Process each line as needed
        lines.append(float(line.strip()))

# %%
pop_measure_lock = []
pop_measure_cas = []
push_measure_lock = []
push_measure_cas = []
counter = 0

nb_threads = 16
for i in range(1, nb_threads+1):
    
    pop_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_lock)

for i in range(1, nb_threads+1):
    
    pop_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(pop_measure_cas)

for i in range(1, nb_threads+1):
    
    push_measure_lock.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_lock)

for i in range(1, nb_threads+1):
    
    push_measure_cas.append(sum(lines[counter:counter+i])/i)
    counter += i
    

print(push_measure_cas)
# Out:
# [0.09884, 0.202121, 0.17375566666666664, 0.255866, 0.2886712, 0.30334883333333335, 0.33886814285714284, 0.347296375, 0.34578133333333333, 0.49351130000000004, 0.4354395454545454, 0.5001758333333334, 0.47411923076923085, 0.5266488571428571, 0.5529062, 0.60694825]
# [0.074734, 0.27071100000000003, 0.354647, 0.4000545, 0.4370900000000001, 0.41385116666666666, 0.46482814285714286, 0.498550375, 0.4371581111111111, 0.48200089999999995, 0.46838981818181824, 0.4832806666666667, 0.4743660769230769, 0.44877842857142847, 0.4535588666666666, 0.538211]
# [0.294138, 0.5277069999999999, 0.5235843333333333, 0.61117075, 0.6555872, 0.6920536666666667, 0.7199007142857143, 0.73383175, 0.7656605555555556, 0.8002359999999997, 0.773793818181818, 0.8172930833333334, 0.8671821538461539, 0.8461240714285714, 0.8394604000000001, 0.8476844375000001]
# [0.288607, 0.460108, 0.6992039999999999, 0.7592420000000001, 0.7948686, 0.761084, 0.7764127142857145, 0.7117132500000001, 0.6216837777777777, 0.6031538000000001, 0.5561985454545455, 0.5808013333333333, 0.5667133846153846, 0.5118584285714285, 0.531169, 0.532489125]

# %%
import matplotlib.pyplot as plt


plt.plot(pop_measure_lock, label='pop_measure_lock')
plt.plot(pop_measure_cas, label='pop_measure_cas')
plt.plot(push_measure_lock, label='push_measure_lock')
plt.plot(push_measure_cas, label='push_measure_cas')

# Adding labels and title
plt.xlabel('THREADS')
plt.ylabel('TIME')
plt.title('TIMINIG')

# Adding legend
plt.legend()

# Display the plot
plt.show()
